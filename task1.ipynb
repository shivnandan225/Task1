# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('carprice.zip')

# %%
df.head()
# Out:
#                     CarName      carbody drivewheel enginelocation fueltype  \
# 0        alfa-romero giulia  convertible        rwd          front      gas
# 1       alfa-romero stelvio  convertible        rwd          front      gas
# 2  alfa-romero Quadrifoglio    hatchback        rwd          front      gas
# 3               audi 100 ls        sedan        fwd          front      gas
# 4                audi 100ls        sedan        4wd          front      gas
#
#   aspiration doornumber cylindernumber enginetype fuelsystem  ...  curbweight  \
# 0        std        two           four       dohc       mpfi  ...        2548
# 1        std        two           four       dohc       mpfi  ...        2548
# 2        std        two            six       ohcv       mpfi  ...        2823
# 3        std       four           four        ohc       mpfi  ...        2337
# 4        std       four           five        ohc       mpfi  ...        2824
#
# ...

# %%
df.shape
# Out:
# (210, 25)

# %%
df.columns
# Out:
# Index(['CarName', 'carbody', 'drivewheel', 'enginelocation', 'fueltype',
#        'aspiration', 'doornumber', 'cylindernumber', 'enginetype',
#        'fuelsystem', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CarName           210 non-null    object
#  1   carbody           210 non-null    object
#  2   drivewheel        210 non-null    object
#  3   enginelocation    210 non-null    object
#  4   fueltype          210 non-null    object
#  5   aspiration        210 non-null    object
#  6   doornumber        210 non-null    object
#  7   cylindernumber    210 non-null    object
#  8   enginetype        210 non-null    object
#  9   fuelsystem        210 non-null    object
#  10  symboling         210 non-null    int64
#  11  wheelbase         210 non-null    float64
#  12  carlength         210 non-null    float64
#  13  carwidth          210 non-null    float64
#  14  carheight         210 non-null    float64
#  15  curbweight        210 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# CarName             0
# carbody             0
# drivewheel          0
# enginelocation      0
# fueltype            0
# aspiration          0
# doornumber          0
# cylindernumber      0
# enginetype          0
# fuelsystem          0
# symboling           0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df_categorical = ['CarName', 'carbody', 'drivewheel', 'enginelocation', 'fueltype',
       'aspiration', 'doornumber', 'cylindernumber', 'enginetype',
       'fuelsystem']

# %%
df_numeric = ['curbweight', 'enginesize', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
       'price']

# %%
# data visualization


for cols in df_numeric:
  plt.figure(figsize=(6,4))
  sns.histplot(df[cols],kde=True)

# %%
sns.countplot(x=df['compressionratio'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df['enginetype'])
# Out:
# <Axes: xlabel='enginetype', ylabel='count'>

# %%
sns.countplot(x=df['fuelsystem'])
# Out:
# <Axes: xlabel='fuelsystem', ylabel='count'>

# %%
for cols in df_numeric:
  plt.figure(figsize=(6,4))
  sns.boxplot(x=df[cols])

# %%
plt.figure(figsize=(10,9))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
#data cleaning and preprocessing





df_cleaned = df.copy()

# %%
df_cleaned.isnull().sum()
# Out:
# CarName             0
# carbody             0
# drivewheel          0
# enginelocation      0
# fueltype            0
# aspiration          0
# doornumber          0
# cylindernumber      0
# enginetype          0
# fuelsystem          0
# symboling           0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df_cleaned.shape
# Out:
# (210, 25)

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.shape
# Out:
# (205, 25)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CarName           205 non-null    object
#  1   carbody           205 non-null    object
#  2   drivewheel        205 non-null    object
#  3   enginelocation    205 non-null    object
#  4   fueltype          205 non-null    object
#  5   aspiration        205 non-null    object
#  6   doornumber        205 non-null    object
#  7   cylindernumber    205 non-null    object
#  8   enginetype        205 non-null    object
#  9   fuelsystem        205 non-null    object
#  10  symboling         205 non-null    int64
#  11  wheelbase         205 non-null    float64
#  12  carlength         205 non-null    float64
#  13  carwidth          205 non-null    float64
#  14  carheight         205 non-null    float64
#  15  curbweight        205 non-null    int64
# ...

# %%
df_cleaned.columns
# Out:
# Index(['CarName', 'carbody', 'drivewheel', 'enginelocation', 'fueltype',
#        'aspiration', 'doornumber', 'cylindernumber', 'enginetype',
#        'fuelsystem', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df_cleaned.drop(columns = ['enginelocation','symboling','carheight','curbweight','stroke','compressionratio','peakrpm'],inplace=True)

# %%
df_cleaned.head()
# Out:
#                     CarName      carbody drivewheel fueltype aspiration  \
# 0        alfa-romero giulia  convertible        rwd      gas        std
# 1       alfa-romero stelvio  convertible        rwd      gas        std
# 2  alfa-romero Quadrifoglio    hatchback        rwd      gas        std
# 3               audi 100 ls        sedan        fwd      gas        std
# 4                audi 100ls        sedan        4wd      gas        std
#
#   doornumber cylindernumber enginetype fuelsystem  wheelbase  carlength  \
# 0        two           four       dohc       mpfi       88.6      168.8
# 1        two           four       dohc       mpfi       88.6      168.8
# 2        two            six       ohcv       mpfi       94.5      171.2
# 3       four           four        ohc       mpfi       99.8      176.6
# 4       four           five        ohc       mpfi       99.4      176.6
#
#    carwidth  enginesize  boreratio  horsepower  citympg  highwaympg    price
# ...

# %%
df_cleaned['carbody'].value_counts()
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
df_cleaned['drivewheel'].value_counts()
# Out:
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %%
df_cleaned['fueltype'].value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
df_cleaned['aspiration'].value_counts()
# Out:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
df_cleaned['doornumber'].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
df_cleaned['cylindernumber'].value_counts()
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: count, dtype: int64

# %%
df_cleaned['enginetype'].value_counts()
# Out:
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64

# %%
df_cleaned['fuelsystem'].value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
df_cleaned['drivewheel']=df_cleaned['drivewheel'].map({
    'rwd':0,
    'fwd':1,
    '4wd':2
})

# %%
df_cleaned['fueltype']=df_cleaned['fueltype'].map({
    'gas':0,
    'diesel':1
})

# %%
df_cleaned['aspiration']=df_cleaned['aspiration'].map({
    'std':0,
    'turbo':1
})

# %%
df_cleaned['doornumber']=df_cleaned['doornumber'].map({
    'four': 0,
    'two':1,
})

# %%
print(df_cleaned.columns.tolist())
# Out:
# ['CarName', 'carbody', 'drivewheel', 'fueltype', 'aspiration', 'doornumber', 'cylindernumber', 'enginetype', 'fuelsystem', 'wheelbase', 'carlength', 'carwidth', 'enginesize', 'boreratio', 'horsepower', 'citympg', 'highwaympg', 'price']

# %%
df_cleaned = pd.get_dummies(df_cleaned,columns=['cylindernumber','enginetype','fuelsystem'],drop_first=True)

# %%
df_cleaned.head()
# Out:
#                     CarName      carbody  drivewheel  fueltype  aspiration  \
# 0        alfa-romero giulia  convertible           0         0           0
# 1       alfa-romero stelvio  convertible           0         0           0
# 2  alfa-romero Quadrifoglio    hatchback           0         0           0
# 3               audi 100 ls        sedan           1         0           0
# 4                audi 100ls        sedan           2         0           0
#
#    doornumber  wheelbase  carlength  carwidth  enginesize  ...  \
# 0           1       88.6      168.8      64.1         130  ...
# 1           1       88.6      168.8      64.1         130  ...
# 2           1       94.5      171.2      65.5         152  ...
# 3           0       99.8      176.6      66.2         109  ...
# 4           0       99.4      176.6      66.4         136  ...
#
#    enginetype_ohcf  enginetype_ohcv  enginetype_rotor  fuelsystem_2bbl  \
# ...

# %%
df_cleaned = pd.get_dummies(df_cleaned , drop_first=True)

# %%
df_cleaned = df_cleaned.astype(int)

# %%
df_cleaned.head()
# Out:
#    drivewheel  fueltype  aspiration  doornumber  wheelbase  carlength  \
# 0           0         0           0           1         88        168
# 1           0         0           0           1         88        168
# 2           0         0           0           1         94        171
# 3           1         0           0           0         99        176
# 4           2         0           0           0         99        176
#
#    carwidth  enginesize  boreratio  horsepower  ...  CarName_volvo 245  \
# 0        64         130          3         111  ...                  0
# 1        64         130          3         111  ...                  0
# 2        65         152          2         154  ...                  0
# 3        66         109          3         102  ...                  0
# 4        66         136          3         115  ...                  0
#
#    CarName_volvo 246  CarName_volvo 264gl  CarName_volvo diesel  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
cols  = ['carlength','wheelbase','carwidth','enginesize','horsepower']

# %%
df_cleaned[cols] = scaler.fit_transform(df_cleaned[cols])

# %%
df_cleaned.head()
# Out:
#    drivewheel  fueltype  aspiration  doornumber  wheelbase  carlength  \
# 0           0         0           0           1  -1.701698  -0.454433
# 1           0         0           0           1  -1.701698  -0.454433
# 2           0         0           0           1  -0.710183  -0.209063
# 3           1         0           0           0   0.116080   0.199887
# 4           2         0           0           0   0.116080   0.199887
#
#    carwidth  enginesize  boreratio  horsepower  ...  CarName_volvo 245  \
# 0 -0.655847    0.074449          3    0.174483  ...                  0
# 1 -0.655847    0.074449          3    0.174483  ...                  0
# 2 -0.192231    0.604046          2    1.264536  ...                  0
# 3  0.271385   -0.431076          3   -0.053668  ...                  0
# 4  0.271385    0.218885          3    0.275883  ...                  0
#
#    CarName_volvo 246  CarName_volvo 264gl  CarName_volvo diesel  \
# ...
